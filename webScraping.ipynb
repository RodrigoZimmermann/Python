# %%
# !which chromedriver
# !pip install selenium
# !apt-get update
# !apt install -y chromium-chromedriver

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd

chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument('--disable-extensions')
chrome_options.add_argument('--disable-gpu')

DRIVER_PATH = '/usr/lib/chromium-browser/chromedriver'
driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)

navegador = webdriver.Chrome(options=chrome_options)
nav2 = webdriver.Chrome(options=chrome_options)

Projeto = []
Protocolo = []
DataProtocolo = []
Situacao = []
Processo = []
Autores = []

for index in range(10):
    navegador.get('https://digital.camarablu.sc.gov.br/documentos/tipo:projetos-2/subtipo:103%2C105%2C106%2C102%2C104/ordem:Documento.data%20DESC/page:{index}')
    cards = navegador.find_elements(By.CLASS_NAME, 'list-link')
    print(index)
    for card in cards:        
        text = card.text
        text = text.replace("Protocolo:", "")
        text = text.replace("Data ", "")
        text = text.replace("Situação:", "")
        text = text.replace("Processo:", "")
        
        primeiraQuebra = text.find("\n")
        Projeto.append(text[:primeiraQuebra])
        text = text[primeiraQuebra:]
        
        indexVirgula = text.find(",")
        Protocolo.append(text[:indexVirgula])
        text = text[indexVirgula + 1:]
        
        indexVirgula = text.find(",")
        DataProtocolo.append(text[:indexVirgula])
        text = text[indexVirgula + 1:]
        
        indexVirgula = text.find(",")
        Situacao.append(text[:indexVirgula])
        text = text[indexVirgula + 1:]

        Processo.append(text[0:])

        nav2.get(card.get_attribute('href'))
        values = nav2.find_elements(By.CLASS_NAME, 'info-value')
        Autores.append(values[1].text)
   

info = {"Projeto":Projeto, "Protocolo":Protocolo,"DataProtocolo":DataProtocolo, "Situacao":Situacao, "Processo":Processo, "Autor":Autores}


df = pd.DataFrame(info)

df.to_csv('dataset.csv')

print('acabou')
# Out:
# /usr/lib/chromium-browser/chromedriver
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Hit:1 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Reading package lists... Done
# Reading package lists... Done
# ...
